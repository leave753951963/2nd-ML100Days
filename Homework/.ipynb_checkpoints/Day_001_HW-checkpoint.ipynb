# %% [markdown]
# 作業1.
# Suicide Rates Overview 1985 to 2016(data set)
# 1.你選的這組資料為何重要?
# 對世界有貢獻且可預防自殺
# 2.資料從何而來?
# United Nations Development Program (HDI)
# World Health Organization(  Suicide in the Twenty-First Century [dataset])
# World Bank( GDP)
# 3.蒐集而來的資料型態為何?
# 結構化
# 4.這組資料想解決的問題如何評估?
# 依據HDI及GDP可看出一個國家數據集的可考性，例如發展較緩慢的國家會產生較不健全的自殺數據(考慮到法律、多層的醫學根據問題)，再參考各國所提出的suicide data。
# 其匯集的參考資料包含country, year, sex, age group, count of suicides, population, suicide rate, country-year composite key, HDI for year, gdp_for_year, gdp_per_capita, generation (based on age grouping average).

# %% [markdown]
# 作業2.
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 	*
# 以最低成本與人力載到需乘坐的客人（動線規劃）
# 	*
# 宣傳優勢（提及數據裡顯示人們在搭車時會想得到的回饋ex.價格、速度、舒適、安全）
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 	*
# 各個年齡層之間無交通工具的人數
# 	*
#  各個年齡層有座過自由載客車隊的人所乘坐的頻率
# 	*
# 各個年齡層消費時所希望得到的回饋
# 	*
# 整個台灣地區每週超過三次消費於自由載客車隊的人的分佈
#
#
# 3. 蒐集而來的資料型態為何
# 	*
# 結構化-（各個年齡層之間無交通工具的人數）
# 	*
# 結構化（各個年齡層有座過自由載客車隊的人所乘坐的頻率）
# 	*
# 結構化-（各個年齡層消費時所希望得到的回饋）
# 	*
# 非結構化-（整個台灣地區每週超過三次消費於自由載客車隊的人的分佈）
# 	*
#
#
#
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error():
    """
    請完成這個 Function 後往下執行
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5eedadaa368e> in <module>
#       1 # 執行 Function, 確認有沒有正常執行
# ----> 2 MSE = mean_squared_error(y, y_hat)
#       3 MAE = mean_absolute_error(y, y_hat)
#       4 print("The Mean squared error is %.3f" % (MSE))
#       5 print("The Mean absolute error is %.3f" % (MAE))
#
# TypeError: mean_squared_error() takes 0 positional arguments but 2 were given
